# %%
# Download GPT2 files

# %%
# !az login --use-device-code
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code EP5228MH4 to authenticate.
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "ef308f52-6af5-4775-a57e-23e68ab0ada3",
#     "id": "b3ab754e-fa59-434d-afb9-2168d11639fb",
#     "isDefault": true,
#     "managedByTenants": [],
#     "name": "Azure for Students",
#     "state": "Enabled",
#     "tenantId": "ef308f52-6af5-4775-a57e-23e68ab0ada3",
#     "user": {
#       "name": "pchlenski@gmail.com",
#       "type": "user"
#     }
#   }
# ]

# %%
# !az account show
# Out:
# {
#   "environmentName": "AzureCloud",
#   "homeTenantId": "ef308f52-6af5-4775-a57e-23e68ab0ada3",
#   "id": "b3ab754e-fa59-434d-afb9-2168d11639fb",
#   "isDefault": true,
#   "managedByTenants": [],
#   "name": "Azure for Students",
#   "state": "Enabled",
#   "tenantId": "ef308f52-6af5-4775-a57e-23e68ab0ada3",
#   "user": {
#     "name": "pchlenski@gmail.com",
#     "type": "user"
#   }
# }

# %%
outdir = "../data/external/openai_sae/"

# !mkdir -p {outdir}/mlp_post_act/records
# !mkdir -p {outdir}/resid_delta_mlp/records

account_name = "openaipublic"
container_name = "sparse-autoencoder"
flags = f"--account-name {account_name} --container-name {container_name} --output none"


for autoencoder_input in ["mlp_post_act", "resid_delta_mlp"]:
    for layer_index in range(12):
        # ae_path = f"gpt2-small/{autoencoder_input}/autoencoders/{layer_index}.pt"
        # !az storage blob download {flags} --name {ae_path} --file {outdir}/{autoencoder_input}/{layer_index}.pt
        for latent_index in range(32768):
            nr_path = f"gpt2-small/{autoencoder_input}/collated_activations/{layer_index}/{latent_index}.json"
            # !az storage blob download {flags} --name {nr_path} --file {outdir}/{autoencoder_input}/records/{layer_index}_{latent_index}.json
# Out:
# There are no credentials provided in your command and environment, we will query for account key for your storage account.
# It is recommended to provide --connection-string, --account-key or --sas-token in your command as credentials.
#
# You also can add `--auth-mode login` in your command to use Azure Active Directory (Azure AD) for authorization if your login account is assigned required RBAC roles.
# For more information about RBAC roles in storage, visit https://docs.microsoft.com/azure/storage/common/storage-auth-aad-rbac-cli.
#
# In addition, setting the corresponding environment variables can avoid inputting credentials in your command. Please use --help to get more information about environment variable usage.
#
# Skip querying account key due to failure: Storage account 'openaipublic' not found.
# Finished[#############################################################]  100.0000%
#
# ...
